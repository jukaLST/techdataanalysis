# %% [markdown]
# <a href="https://colab.research.google.com/github/jukaLST/techdataanalysis/blob/main/task_5_12_24_JO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# DATAFRAME

df = pd.read_csv('/content/programming_basics21112024 (1).csv')

# %%
df
df.head()
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# ...

# %%
type(df["Name"])
df[["Name", "Age", "Sex"]]
df["Age"].median()
# Out:
# 28.0

# %%
import pandas as pd

# %%
MAIN_DF = pd.read_csv("/content/programming_basics21112024 (1).csv")
df = MAIN_DF

# %%
df["Age"].median()
# Out:
# 28.0

# %%
df["Sex"] = df["Sex"].replace({"male": 0, "female":1})
# Out:
# <ipython-input-10-c0a7928e4380>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Sex"] = df["Sex"].replace({"male": 0, "female":1})

# %%
df["Sex"].value_counts()
# Out:
# Sex
# 0    577
# 1    314
# Name: count, dtype: int64

# %%
titanic_disaster = 1912
df["Year of birth"] = [titanic_disaster - age for age in df["Age"]]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1
# 2                               Heikkinen, Miss. Laina    1  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1
# 4                             Allen, Mr. William Henry    0  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
function()

#print()
#type()

# %%
def printer():
  print("I AM ALIVE")

# %%
printer()
# Out:
# I AM ALIVE

# %%
def printer2(text):
  print(text)

# %%
printer2("la l sl s")
# Out:
# la l sl s

# %%
def substraction(num1, num2):
  print(num1-num2)

# %%
x = substraction(222,24)
# Out:
# 198

# %%
text = Wa$sae*kk
text.replace("$", "").replace("*", "").lower().strip().title()
# Out:
#   File "<ipython-input-28-0724a159cacf>", line 1
#     text = Wa$sae*kk
#              ^
# SyntaxError: invalid syntax

# %%
text2 = "GHGHFGHFGHFGHFfdfdf"
text2.replace

# %%
df = pd.DataFrame({"Name": ["Patryk", "Ola", "Ala"], "Points" : [1, 25, 50]})

# %%
df
# Out:
#      Name  Points
# 0  Patryk       1
# 1     Ola      25
# 2     Ala      50

# %%
def grade(points):
  if points > 45:
    return "A"
  elif points < 45 and points > 20:
    return "B"
  else:
    return "meh"

# %%
grade(17)
# Out:
# 'meh'

# %%
df["Grade"] = df["Points"].apply(grade)
df
# Out:
#      Name  Points Grade
# 0  Patryk       1   meh
# 1     Ola      25     B
# 2     Ala      50     A

# %%
def rectangle_area(length, width):
  return length * width

# %%
rectangle_area(4, 5)
# Out:
# 20

# %%
def is_even(number):
  if number % 2 == 0:
    print("even")
    return True
  else:
    return False

# %%
is_even(44)
# Out:
# even
# True

# %%
def convert_to_celsius(temperature):
  return (temperature - 32)*5/9

# %%
convert_to_celsius(100)
# Out:
# 37.77777777777778

# %%
import pandas as pd

my_data = pd.read_csv("/content/titanic.csv")
df = my_data.copy()

# %%
df["Over30"]=df['Age']>30
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
