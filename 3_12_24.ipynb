# %% [markdown]
# <a href="https://colab.research.google.com/github/jukaLST/techdataanalysis/blob/main/3_12_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json


with open('students.json') as file:
  data=json.load(file)
  students = data['students']
  #for student in students:
    #print(student['name'])

  print(students[1]['name'])
# Out:
# Bob

# %%
BASEURL = "http://api.geonames.org/findNearbyPlaceNameJSON"
USERNAME = "juka16"

import requests


parameters = {"lng": "-0.12574","lat": "51.50853", "username": USERNAME }

response = requests.get(BASEURL, parameters)
json_data=response.json()['geonames']
print(json.dumps(json_data,indent = 2))
# Out:
# [
#   {
#     "adminCode1": "ENG",
#     "lng": "-0.12574",
#     "distance": "0.00019",
#     "geonameId": 2643743,
#     "toponymName": "London",
#     "countryId": "2635167",
#     "fcl": "P",
#     "population": 8961989,
#     "countryCode": "GB",
#     "name": "London",
#     "fclName": "city, village,...",
#     "adminCodes1": {
#       "ISO3166_2": "ENG"
#     },
#     "countryName": "United Kingdom",
#     "fcodeName": "capital of a political entity",
#     "adminName1": "England",
#     "lat": "51.50853",
#     "fcode": "PPLC"
#   }
# ]

# %%
BASEURL = "http://api.geonames.org/searchJSON"
USERNAME = "juka16"

import requests


parameters = {"name":"London", "username": USERNAME }

response = requests.get(BASEURL, parameters)
json_data=response.json()['geonames']
print(json.dumps(json_data,indent = 2))
# Out:
# [
#   {
#     "adminCode1": "ENG",
#     "lng": "-0.12574",
#     "geonameId": 2643743,
#     "toponymName": "London",
#     "countryId": "2635167",
#     "fcl": "P",
#     "population": 8961989,
#     "countryCode": "GB",
#     "name": "London",
#     "fclName": "city, village,...",
#     "adminCodes1": {
#       "ISO3166_2": "ENG"
#     },
#     "countryName": "United Kingdom",
#     "fcodeName": "capital of a political entity",
#     "adminName1": "England",
#     "lat": "51.50853",
#     "fcode": "PPLC"
#   },
#   {
#     "adminCode1": "ENG",
#     "lng": "-0.30864",
#     "geonameId": 11591955,
#     "toponymName": "London",
#     "countryId": "2635167",
#     "fcl": "L",
#     "population": 8787892,
#     "countryCode": "GB",
#     "name": "London",
#     "fclName": "parks,area, ...",
#     "adminCodes1": {
#       "ISO3166_2": "ENG"
#     },
#     "countryName": "United Kingdom",
#     "fcodeName": "region",
#     "adminName1": "England",
#     "lat": "51.49227",
# ...
